# %% [markdown]
# # Task 1: Environment Setup & First Python Script
#
# Name: **Awais Ramzan**
#
# **Goal:**
# Set up the Python development environment, create the first Python program, and document the complete process.

# %% [markdown]
# # Software Installed
#
# The following software was installed:
#
# - Python 3.14
# - Visual Studio Code
# - Git
# - Jupyter Notebook

# %% [markdown]
# # Installation Steps
#
# ### Step 1
# Downloaded and installed Python from python.org.
#
# ### Step 2
# Checked "Add Python to PATH" during installation.
#
# ### Step 3
# Installed Visual Studio Code.
#
# ### Step 4
# Installed Git.
#
# ### Step 5
# Opened VS Code.
#
# ### Step 6
# Opened the project folder.
#
# ### Step 7
# Created app.py.
#
# ### Step 8
# Run the Python program in the terminal.

# %%
print("Hi, this is Awais Ramzan, future AI engineer!")
# Out:
# Hi, this is Awais Ramzan, future AI engineer!

# %% [markdown]
# # Screenshots
#
# ### python intallation
# ![image.png](attachment:image.png)
#
# ### Vs code window
#
# ![image-2.png](attachment:image-2.png)
#
# ### Terminal showning execution
# ![First App.py ss.png](<attachment:First App.py ss.png>)

# %% [markdown]
# # Troubleshooting Notes
#
# ### Issue 1
#
# Python command was not recognized.
#
# **Solution**
#
# Verified that Python was installed and added to the system PATH.
#
# ---
#
# ### Issue 2
#
# VS Code did not detect Python interpreter.
#
# **Solution**
#
# Selected the correct interpreter using:
#
# Ctrl + Shift + P
#
# Python: Select Interpreter
#
# ---
#
# ### Issue 3
#
# Incorrect working directory.
#
# **Solution**
#
# Navigated to the project folder before running the script using the `cd` command.

# %% [markdown]
# # Conclusion
#
# The Python development environment was successfully configured.
#
# The first Python program was executed successfully using VS Code, and the environment is now ready for future AI engineering tasks.
